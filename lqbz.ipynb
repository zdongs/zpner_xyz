# %%
import pandas as pd
df = pd.read_csv("d:/AI/bossbase/boin.csv")
dupdf = df[df.duplicated(subset=["岗位要求","更新时间"], keep=False)]
dupdf
# Out:
#              岗位名称          区位          薪资  工作经验  学历    关键词1       关键词2  \
# 6       AI算法模型工程师   北京·昌平区·沙河      25-50K  经验不限  本科   大模型算法       图像算法
# 21      AI算法模型工程师   北京·昌平区·沙河      25-50K  1-3年  本科   无明显侧重        NaN
# 22      AI算法模型工程师          北京      25-50K  1-3年  本科    深度学习       强化学习
# 38      AI算法模型工程师  北京·西城区·复兴门      25-50K  1-3年  本科    深度学习  模型加速/性能优化
# 43            NLP   北京·朝阳区·国贸      15-30K  1-3年  本科    Java      C/C++
# ...           ...         ...         ...   ...  ..     ...        ...
# 1345     自然语言处理算法   北京·朝阳区·国贸      15-30K  1-3年  本科    Java      C/C++
# 1347       自然语言处理   北京·海淀区·上地      13-20K  经验不限  本科    全职工作     标注数据分析
# 1377       自然语言处理   北京·海淀区·上地      12-20K  经验不限  本科    全职工作     标注方法优化
# 1391  风控情报数据挖掘工程师  北京·朝阳区·亚运村  50-80K·15薪  3-5年  本科  Python     风控相关经验
# 1393      数据挖掘工程师          北京  30-50K·15薪  经验不限  本科    数据挖掘        NaN
#
#         关键词3        企业名称   企业类别        企业规模  \
# 6        SQL  中移动金融全资子公司  互联网金融    500-999人
# ...
